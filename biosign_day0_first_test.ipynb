# %% [markdown]
# <a href="https://colab.research.google.com/github/MituShil/biosign-dashboard-/blob/main/biosign_day0_first_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello!I am building the Biosign Dasgboard")
# Out:
# Hello!I am building the Biosign Dasgboard

# %%
print("This project scores exoplanets for biosignature likelihood")
# Out:
# This project scores exoplanets for biosignature likelihood

# %%
print("Built by: Mitu Shil")
# Out:
# Built by: Mitu Shil
